# %%
from allensdk.core.brain_observatory_cache import BrainObservatoryCache
import pprint
from pathlib import Path
# This class uses a 'manifest' to keep track of downloaded data and metadata.  
# All downloaded files will be stored relative to the directory holding the manifest
# file.  If 'manifest_file' is a relative path (as it is below), it will be 
# saved relative to your working directory.  It can also be an absolute path.
boc =  BrainObservatoryCache(
    manifest_file=str(Path('/home/maria/Documents/AllenBrainObservatory') / 'brain_observatory_manifest.json'))

# Download a list of all targeted areas
targeted_structures = boc.get_all_targeted_structures()
print("all targeted structures: " + str(targeted_structures))
# Out:
# all targeted structures: ['VISal', 'VISam', 'VISl', 'VISp', 'VISpm', 'VISrl']

# %%
exps = boc.get_experiment_containers(ids=[517409552])

# %%
import pandas as pd

# Download cells for a set of experiments and convert to DataFrame
cells = boc.get_cell_specimens()
cells = pd.DataFrame.from_records(cells)

# %%
cells[cells['cell_specimen_id']==517409552]
# Out:
#       all_stim  area  cell_specimen_id  \
# 1023      True  VISp         517409552
#
#                                     donor_full_genotype    dsi_dg  \
# 1023  Cux2-CreERT2/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP6...  0.513873
#
#       experiment_container_id  failed_experiment_container  g_dsi_dg  \
# 1023                511509529                        False  0.244311
#
#       g_osi_dg  g_osi_sg  ...  specimen_id   tfdi_dg  time_to_peak_ns  \
# 1023  0.034427  0.656206  ...    495726993  0.322153           0.3317
#
#       time_to_peak_sg    tld1_id     tld1_name      tld2_id   tld2_name  \
# 1023          0.19902  177839004  Cux2-CreERT2  177837320.0  Camk2a-tTA
#
#         tlr1_id           tlr1_name
# 1023  265943423  Ai93(TITL-GCaMP6f)
#
# [1 rows x 60 columns]

# %%
cells.columns
# Out:
# Index(['all_stim', 'area', 'cell_specimen_id', 'donor_full_genotype', 'dsi_dg',
#        'experiment_container_id', 'failed_experiment_container', 'g_dsi_dg',
#        'g_osi_dg', 'g_osi_sg', 'image_sel_ns', 'imaging_depth', 'osi_dg',
#        'osi_sg', 'p_dg', 'p_ns', 'p_run_mod_dg', 'p_run_mod_ns',
#        'p_run_mod_sg', 'p_sg', 'peak_dff_dg', 'peak_dff_ns', 'peak_dff_sg',
#        'pref_dir_dg', 'pref_image_ns', 'pref_ori_sg', 'pref_phase_sg',
#        'pref_sf_sg', 'pref_tf_dg', 'reliability_dg', 'reliability_nm1_a',
#        'reliability_nm1_b', 'reliability_nm1_c', 'reliability_nm2',
#        'reliability_nm3', 'reliability_ns', 'reliability_sg',
#        'rf_area_off_lsn', 'rf_area_on_lsn', 'rf_center_off_x_lsn',
#        'rf_center_off_y_lsn', 'rf_center_on_x_lsn', 'rf_center_on_y_lsn',
#        'rf_chi2_lsn', 'rf_distance_lsn', 'rf_overlap_index_lsn', 'run_mod_dg',
#        'run_mod_ns', 'run_mod_sg', 'sfdi_sg', 'specimen_id', 'tfdi_dg',
# ...

# %%
cells[cells['cell_specimen_id']==517409552].image_sel_ns
# Out:
# 1023    0.569017
# Name: image_sel_ns, dtype: float64

# %%
cells[cells['cell_specimen_id']==517471803]
# Out:
#       all_stim  area  cell_specimen_id  \
# 4776      True  VISp         517471803
#
#                                     donor_full_genotype  dsi_dg  \
# 4776  Cux2-CreERT2/wt;Camk2a-tTA/wt;Ai93(TITL-GCaMP6...     NaN
#
#       experiment_container_id  failed_experiment_container  g_dsi_dg  \
# 4776                511510736                        False  0.984286
#
#       g_osi_dg  g_osi_sg  ...  specimen_id   tfdi_dg  time_to_peak_ns  \
# 4776  0.945273  0.685616  ...    495727015  0.332021          0.29925
#
#       time_to_peak_sg    tld1_id     tld1_name      tld2_id   tld2_name  \
# 4776          0.03325  177839004  Cux2-CreERT2  177837320.0  Camk2a-tTA
#
#         tlr1_id           tlr1_name
# 4776  265943423  Ai93(TITL-GCaMP6f)
#
# [1 rows x 60 columns]

# %%
sig_neurons=[23,
 54,
 160,
 179,
 200,
 207,
 211,
 226,
 231,
 243,
 270,
 290,
 292,
 296,
 304,
 308,
 312,
 322,
 325,
 329,
 332,
 335,
 346,
 354,
 355,
 376,
 395,
 402,
 404,
 416,
 433,
 440,
 443,
 454,
 458,
 478,
 483,
 492,
 501,
 506,
 517,
 563,
 580,
 593,
 596,
 606,
 615,
 623,
 657,
 664,
 671,
 673,
 675,
 692,
 718,
 731,
 743,
 762,
 773,
 777,
 799,
 805,
 826,
 835,
 843,
 865,
 882,
 903,
 912,
 940,
 950,
 970,
 974,
 976,
 988,
 996,
 1010,
 1022,
 1031,
 1045,
 1046,
 1052,
 1067,
 1068,
 1071,
 1073,
 1075,
 1079,
 1095,
 1096,
 1099,
 1105,
 1114,
 1117,
 1121,
 1126,
 1134,
 1139,
 1151,
 1156,
 1162,
 1168,
 1191,
 1204,
 1218,
 1229,
 1230,
 1236,
 1245,
 1249,
 1262,
 1273,
 1275,
 1290,
 1297,
 1300,
 1319,
 1330,
 1337,
 1338,
 1342,
 1343,
 1347,
 1359,
 1370,
 1377,
 1404,
 1407,
 1421,
 1422,
 1425,
 1426,
 1429,
 1474,
 1485,
 1503,
 1507,
 1524,
 1535,
 1566,
 1594,
 1622,
 1652,
 1656,
 1735,
 1752,
 1761,
 1762,
 1767,
 1783,
 1802,
 1834,
 1846,
 1981,
 1995,
 1998,
 2001,
 2019,
 2081,
 2099,
 2104,
 2106,
 2111,
 2119,
 2152,
 2158,
 2159,
 2163,
 2170,
 2175,
 2178,
 2180,
 2185,
 2188,
 2196,
 2203,
 2214,
 2216,
 2217,
 2219,
 2231,
 2237,
 2248,
 2256,
 2263,
 2266,
 2268,
 2292,
 2311,
 2314,
 2320,
 2333,
 2354,
 2372,
 2373,
 2386,
 2391,
 2397,
 2414,
 2478,
 2489,
 2764,
 2769,
 2773,
 2812,
 2892,
 2904,
 2909,
 2940,
 2971,
 3003,
 3082,
 3084,
 3094,
 3103,
 3117,
 3121,
 3131,
 3134,
 3161,
 3223,
 3226,
 3241,
 3250,
 3251,
 3254,
 3261,
 3263,
 3266,
 15102,
 15103,
 15107,
 15118,
 15122,
 15123,
 15126,
 15129,
 15130,
 15133,
 15137,
 15145,
 15147,
 15151,
 15165,
 15167,
 15168,
 15171,
 15177,
 15183,
 15190,
 15195,
 15197,
 15198,
 15223,
 15225,
 15236,
 15242,
 15262,
 15301,
 15331,
 15339,
 15340,
 15343,
 15371,
 15383,
 15385,
 15404,
 15406,
 15461,
 15504,
 15517,
 15529,
 15537,
 15545,
 15563,
 15608,
 15627,
 15653,
 15715,
 15719,
 15764,
 15767,
 15778,
 15821,
 15848,
 15852,
 15858,
 15863,
 15896,
 15908,
 15914,
 15953,
 15961,
 16023,
 16120,
 16162,
 16169,
 16561,
 16753,
 16763,
 16773,
 16781,
 16791,
 16799,
 16818,
 16829,
 16851,
 16862,
 17166,
 17167,
 17181,
 17194,
 17312,
 17313,
 17314,
 17316,
 17328,
 17330,
 17341,
 17343,
 17378,
 17509,
 17577,
 17587,
 17659,
 17742,
 17743,
 17795,
 17797,
 17827,
 17854,
 17855,
 17868,
 17874,
 17875,
 17881,
 17884,
 17885,
 17898,
 17913,
 17916,
 17943,
 17948,
 17949,
 17973,
 17976,
 17982,
 17986,
 17991,
 18040,
 18041,
 18071,
 18100,
 18111,
 18151,
 18183,
 18231,
 18242,
 18291,
 18308,
 18325,
 18362,
 18374,
 18377,
 18390,
 18395,
 18409,
 18410,
 18420,
 18422,
 18425,
 18430,
 18723,
 18950,
 18971,
 18978,
 19283,
 19284,
 19302,
 19313,
 19516,
 19597,
 19615,
 19619,
 19632,
 19636,
 19644,
 19667,
 19669,
 19694,
 19695,
 19697,
 19708,
 19712,
 19714,
 19719,
 19727,
 19731,
 19741,
 19744]

# %%
import numpy as np
dat=np.load('/home/maria/LuckyMouse2/pixel_transformer_neuro/data/processed/cell_specimen_ids_in_order.npy')
area_list=[]
for i in sig_neurons:
    print(cells[cells['cell_specimen_id']==dat[i]].area)
    area_list.append(cells[cells['cell_specimen_id']==dat[i]])
# Out:
# 519    VISp
# Name: area, dtype: object
# 575    VISp
# Name: area, dtype: object
# 934    VISp
# Name: area, dtype: object
# 961    VISp
# Name: area, dtype: object
# 986    VISp
# Name: area, dtype: object
# 994    VISp
# Name: area, dtype: object
# 998    VISp
# Name: area, dtype: object
# 1023    VISp
# Name: area, dtype: object
# 1029    VISp
# Name: area, dtype: object
# 1042    VISp
# Name: area, dtype: object
# 1083    VISp
# Name: area, dtype: object
# 1113    VISp
# Name: area, dtype: object
# 1115    VISp
# Name: area, dtype: object
# 1119    VISp
# Name: area, dtype: object
# 1137    VISp
# Name: area, dtype: object
# 1147    VISp
# Name: area, dtype: object
# 1153    VISp
# Name: area, dtype: object
# 28499    VISp
# Name: area, dtype: object
# 28502    VISp
# Name: area, dtype: object
# 28506    VISp
# Name: area, dtype: object
# 28512    VISp
# Name: area, dtype: object
# 28515    VISp
# Name: area, dtype: object
# 28527    VISp
# Name: area, dtype: object
# ...

# %%
import numpy as np
import pandas as pd
from collections import defaultdict

# Load neuron → cell_specimen_id mapping
sig_neurons = np.array(sig_neurons)
specimen_ids = np.load('/home/maria/LuckyMouse2/pixel_transformer_neuro/data/processed/cell_specimen_ids_in_order.npy')

# Build area map and clean
area_map = {}
area_labels = []

for neuron_idx in sig_neurons:
    specimen_id = specimen_ids[neuron_idx]
    area_row = cells[cells['cell_specimen_id'] == specimen_id]
    
    if not area_row.empty:
        area_name = area_row['area'].values[0]
        area_labels.append(area_name)
        area_map[neuron_idx] = area_name
    else:
        print(f"Warning: No match found for neuron {neuron_idx}")
        area_labels.append("Unknown")
        area_map[neuron_idx] = "Unknown"

# Save cleaned area list
np.save("sig_neuron_areas.npy", np.array(area_labels))
print("Saved area labels to sig_neuron_areas.npy")
# Out:
# Saved area labels to sig_neuron_areas.npy

# %%
area_labels
# Out:
# ['VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISp',
#  'VISl',
#  'VISl',
#  'VISl',
# ...

# %%
sig_neurons=[23,
 54,
 160,
 179,
 200,
 207,
 211,
 226,
 231,
 243,
 270,
 290,
 292,
 296,
 304,
 308,
 312,
 322,
 325,
 329,
 332,
 335,
 346,
 354,
 355,
 376,
 395,
 402,
 404,
 416,
 433,
 440,
 443,
 454,
 458,
 478,
 483,
 492,
 501,
 506,
 517,
 563,
 580,
 593,
 596,
 606,
 615,
 623,
 657,
 664,
 671,
 673,
 675,
 692,
 718,
 731,
 743,
 762,
 773,
 777,
 799,
 805,
 826,
 835,
 843,
 865,
 882,
 903,
 912,
 940,
 950,
 970,
 974,
 976,
 988,
 996,
 1010,
 1022,
 1031,
 1045,
 1046,
 1052,
 1067,
 1068,
 1071,
 1073,
 1075,
 1079,
 1095,
 1096,
 1099,
 1105,
 1114,
 1117,
 1121,
 1126,
 1134,
 1139,
 1151,
 1156,
 1162,
 1168,
 1191,
 1204,
 1218,
 1229,
 1230,
 1236,
 1245,
 1249,
 1262,
 1273,
 1275,
 1290,
 1297,
 1300,
 1319,
 1330,
 1337,
 1338,
 1342,
 1343,
 1347,
 1359,
 1370,
 1377,
 1404,
 1407,
 1421,
 1422,
 1425,
 1426,
 1429,
 1474,
 1485,
 1503,
 1507,
 1524,
 1535,
 1566,
 1594,
 1622,
 1652,
 1656,
 1735,
 1752,
 1761,
 1762,
 1767,
 1783,
 1802,
 1834,
 1846,
 1981,
 1995,
 1998,
 2001,
 2019,
 2081,
 2099,
 2104,
 2106,
 2111,
 2119,
 2152,
 2158,
 2159,
 2163,
 2170,
 2175,
 2178,
 2180,
 2185,
 2188,
 2196,
 2203,
 2214,
 2216,
 2217,
 2219,
 2231,
 2237,
 2248,
 2256,
 2263,
 2266,
 2268,
 2292,
 2311,
 2314,
 2320,
 2333,
 2354,
 2372,
 2373,
 2386,
 2391,
 2397,
 2414,
 2478,
 2489,
 2764,
 2769,
 2773,
 2812,
 2892,
 2904,
 2909,
 2940,
 2971,
 3003,
 3082,
 3084,
 3094,
 3103,
 3117,
 3121,
 3131,
 3134,
 3161,
 9784,
 9820,
 9845,
 9961,
 9972,
 9974,
 9985,
 9986,
 9989,
 9996,
 9999,
 10018,
 10025,
 10040,
 10046,
 10052,
 10072,
 10073,
 10078,
 10082,
 10106,
 10131,
 10158,
 10175,
 10178,
 10187,
 10212,
 10213,
 10217,
 10243,
 10247,
 10258,
 10274,
 10287,
 10292,
 10297,
 10307,
 10315,
 10317,
 10323,
 10327,
 10334,
 10336,
 10344,
 10350,
 10355,
 10367,
 10368,
 10391,
 10394,
 10409,
 10411,
 10412,
 10416,
 10417,
 10423,
 10435,
 10442,
 10446,
 10452,
 10458,
 10465,
 10473,
 10480,
 10483,
 10503,
 10508,
 10512,
 10514,
 10515,
 10516,
 10520,
 10534,
 10544,
 10560,
 10577,
 10586,
 10607,
 10646,
 10649,
 10650,
 10661,
 10665,
 10685,
 10712,
 10808,
 10826,
 10932,
 10940,
 10946,
 10948,
 10961,
 10963,
 10964,
 10965,
 10967,
 10970,
 10977,
 10984,
 10987,
 10990,
 10998,
 10999,
 11001,
 11003,
 11175,
 11186,
 11189,
 11198,
 11206,
 11214,
 11223,
 11229,
 11235,
 11236,
 11238,
 11243,
 11248,
 11251,
 11272,
 11278,
 11295,
 11743,
 11890,
 11894,
 11899,
 11931,
 11933,
 11965,
 12013,
 12024,
 12053,
 12064,
 12070,
 12094,
 12099,
 12101,
 12103,
 12104,
 12207,
 12213,
 12217,
 12228,
 12231,
 12279,
 12294,
 12297,
 12308,
 12315,
 12321,
 12322,
 12333,
 12340,
 12341,
 12349,
 12354,
 12361,
 12382,
 12383,
 12387,
 12390,
 12391,
 12414,
 12415,
 12429,
 12437,
 12448,
 12455,
 12460,
 12465,
 12495,
 12616,
 12706,
 12710,
 12713,
 12717,
 12724,
 12732,
 12745,
 12747,
 12748,
 12775,
 12783,
 12787,
 12795,
 12803,
 12809,
 12818,
 12819,
 12828,
 12835,
 12844,
 12855,
 12859,
 12873,
 12888,
 12889,
 13046,
 13055,
 13076]

# %%
area_list
# Out:
# [519    VISp
#  Name: area, dtype: object,
#  575    VISp
#  Name: area, dtype: object,
#  934    VISp
#  Name: area, dtype: object,
#  961    VISp
#  Name: area, dtype: object,
#  986    VISp
#  Name: area, dtype: object,
#  994    VISp
#  Name: area, dtype: object,
#  998    VISp
#  Name: area, dtype: object,
#  1023    VISp
#  Name: area, dtype: object,
#  1029    VISp
#  Name: area, dtype: object,
#  1042    VISp
#  Name: area, dtype: object,
#  1083    VISp
#  Name: area, dtype: object,
#  1113    VISp
#  Name: area, dtype: object,
#  1115    VISp
#  Name: area, dtype: object,
#  1119    VISp
#  Name: area, dtype: object,
#  1137    VISp
#  Name: area, dtype: object,
#  1147    VISp
#  Name: area, dtype: object,
#  1153    VISp
#  Name: area, dtype: object,
#  28499    VISp
#  Name: area, dtype: object,
#  28502    VISp
#  Name: area, dtype: object,
#  28506    VISp
#  Name: area, dtype: object,
#  28512    VISp
#  Name: area, dtype: object,
#  28515    VISp
# ...
